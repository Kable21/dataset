# %%
cd ../Training/
# Out:
# /mnt/d/GAN/dataset/Change of AP/Training

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors

seCheck = np.load('50_50'+'.npy')
xPrintCheck = np.load("SE_" + '147_147' + '.npy')
print(seCheck)

fig, (ax1, ax2) = plt.subplots(2)
ax1.set_title("xPrint")
im1 = ax1.imshow(0 - xPrintCheck, cmap='gray', \
    interpolation='none', norm=colors.Normalize(vmin=-1, vmax=0))       
im1.set_array(0-xPrintCheck)                                                   

ax2.set_title("Strain Energy")
im2 = ax2.imshow(seCheck, cmap='viridis', \
    interpolation='none')       
im2.set_array(seCheck)  
plt.draw()
plt.show()
# Out:
# [[1.00394159e+00 1.00426905e+00 1.00427150e+00 ... 4.42778130e-08
#   4.38678066e-08 4.03029026e-08]
#  [1.00394158e+00 1.00426905e+00 1.00427150e+00 ... 4.42790207e-08
#   4.38683323e-08 4.03031442e-08]
#  [1.00394138e+00 1.00426898e+00 1.00427148e+00 ... 4.42821148e-08
#   4.38696017e-08 4.03037513e-08]
#  ...
#  [1.00393403e+00 1.00426576e+00 1.00426908e+00 ... 1.00426908e+00
#   1.00426576e+00 1.00393403e+00]
#  [1.00371736e+00 1.00416248e+00 1.00416248e+00 ... 1.00416248e+00
#   1.00416248e+00 1.00371736e+00]
#  [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.00000000e+00
#   1.00000000e+00 1.00000000e+00]]
